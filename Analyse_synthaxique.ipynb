# %%
import pandas as pd
import edsnlp
from spacy import displacy

import spacy
import datetime
import re

# %%
# - Listes expressions a eviter
list_embolie_no_MTEV = "|".join(
    [
        " graisseuse",
        " m.?tastatique",
        " septique",
        " bact.?rienne",
        " gazeuse",
    ]
)

# Expression Reguliere : RegEx

regex_MTEV = dict(
    # MTEV
    EP=[
        rf"(?i)embolie(?!.{{0,10}}{list_embolie_no_MTEV})",
        r"(?i)t(|h)romb(us|i\W).{0,50}(pulmonaire|lobaire)",
        r"(?i)infarctus.{0,10}pulmonaire",
        r"\WE\.P\.\W",
        r"\WEP\W",
    ],
)


def build_nlp_pipe_MTEV():
    
    """
    Builds the nlp pipe needed to extract MTEV.

    Returns
    -------
        nlp : object spacy.blank
            EDS-NLP pipeline.
    """
    
    nlp = edsnlp.blank("eds")

    # sentencizer component
    nlp.add_pipe("eds.sentences")
    nlp.add_pipe("eds.normalizer")

    # Matcher component
    nlp.add_pipe(
        "eds.matcher",
        config=dict(regex=regex_MTEV, ignore_excluded=True),
    )

    # Qualifiers
    nlp.add_pipe("eds.negation")  # Negation component
    nlp.add_pipe("eds.hypothesis")  # Speculation pipeline
    nlp.add_pipe("eds.family")  # Family context detection
    nlp.add_pipe(
        "eds.sections"
    )  # Section where entity is quoted

    # Extracting dates
    nlp.add_pipe("eds.dates")

    return nlp



def search_MTEV(note_mtev_df):
    """
    Performs the actual textual search of MTEV entities.

    Parameters
    ----------
        note_mtev_df : DataFrame Pandas
            Notes of CR containing at least the following columns :
            - `person_id`,
            - `visit_occurrence_id`,
            - `note_id`,
            - `note_class_source_value`,
            - `note_datetime`,
            - `note_text`.

    Returns
    -------
        ents_df : DataFrame Pandas
            Containing the MTEV found in the text and the potential associated
            date.
    """
    nlp = build_nlp_pipe_MTEV()

    docs = edsnlp.data.from_pandas(
        note_mtev_df,
        converter="omop",
        doc_attributes=[
            "person_id",
            "visit_occurrence_id",
            "note_class_source_value",
            "note_datetime",
        ],
    )
    # Add the pipeline to operations that will be run
    docs = docs.map_pipeline(nlp)
    # Distribution of the operations of lazy collection on multiple workers
    docs = docs.set_processing(backend="multiprocessing", show_progress=True)
    ents_df = docs.to_pandas(converter=pick_results)

    return ents_df


def separe_paragraphe(ent, nlp):
    """
    This function returns as entity's sentence the paragraph containing the
    entity.

    Parameters
    ----------
        ent : spacy.Span
            Entity found in a doc by nlp pipes.

    Returns
    -------
        tokenizer : spacy.Span
            Paragraph (text surrounded by "\n\n") containing the entity in the
            doc.
    """
    liste = pd.Series(re.split(r"\n\W*\n", ent.sent.text))
    txt = liste[liste.str.contains(ent.text)].reset_index().squeeze()[0]

    debut = ent.sent.text.find(txt)  # re.search(txt, ent.sent.text).start()
    fin = debut + len(txt)  # re.search(txt, ent.sent.text).end()

    tokenizer = spacy.tokenizer.Tokenizer(nlp.vocab)

    return tokenizer(ent.sent.text[debut:fin])






def pick_results(doc):
    """
    This function provides the entities that must be collected by the nlp
    process.

    Parameters
    ----------
        doc : spacy.Doc
            A container with the annotated text.

    Returns
    -------
        list[dict]
            Shape to stock the results for each entity found.
    """
    return [
        {
            "person_id": e.doc._.person_id,
            "visit_occurrence_id": e.doc._.visit_occurrence_id,
            "note_id": e.doc._.note_id,
            "note_class_source_value": e.doc._.note_class_source_value,
            "lexical_variant": e.text,
            "label": e.label_,
            "negation": e._.negation,
            "hypothesis": e._.hypothesis,
            "family": e._.family,
            "sentence":e.sent.text,
            "section": e._.section,
            
            
        }
        for e in doc.ents
        if doc.ents
    ]

# %%
df_CR=pd.read_excel("../Stage_sadjia/CR_.xlsx")

# %%
df_CR
# Out:
#    person_id                        note_title note_class_source_value  \
# 0          1  CR Urgences SAT SAU ACCUEIL (UF)                 INCONNU
# 1          2   CR Urgences BCT URGENCES ADULTE                 INCONNU
#
#         note_datetime                                          note_text
# 0 2021-05-08 20:20:00  Adressé par MDS Faidherbe pour sensation de dy...
# 1 2021-09-10 00:00:00  Compte-rendu de passage aux Urgences\nAL.Score...

# %% [markdown]
# ## Type de comptes rendus

# %%
df_CR.note_text[0]
# Out:
# 'Adressé par MDS Faidherbe pour sensation de dyspnée avec frissons ce jour.\\nTachycardie à l\'IAO. Avis coord : PEC rapide.\\n- Infirme moteur cérébral\\nAsthme\\nDyspnée\\nTA : 111/77 mmHg FC : 104 Puls/min Temp : 37.5 °C FR : 16 /min\\nSpO2 : 99 % EVA : 0 CGS : 15\\nBU : 08/05/2021 21:32\\nLeucocytes : Ø Nitrites : Ø Protéine : + PH : 7.0 Erythrocytes : Ø Densité : 1.0 Cétone : Ø\\nGlucose : Ø\\nPA bras Dt : 156/98 mmHg FC : 145 /mn Temp : 37.8 °C FR : 20 /mn\\nSpO2 : 96% air\\nGCS : 15 (Y: 4/V: 5/M :6)\\nEVA : 0\\nMonsieur VANCIU JANNON\\n9 RUE LEBOUI\\n75014 PARIS 14\\n2/5CR Urgences SAT SAU ACCUEIL (UF), Imprimé le 09/05/2021 02:51\\nPat.: vanciu JANNON | M | 30/01/1996 | 8010143495 | 761236428\\nTraitements habituels\\nMode de vie\\nAnamnèse\\nExamen clinique initial\\nEvolution\\nExamens complémentaires\\nVentoline\\nBaclofène\\nIMC\\nvit en foyer se déplace en fauteuil electrique\\nPatient de 25 ans IMC es déplacant en fauteuil\\naderssé par maison de santé Faidherbe pour dyspnée, douleurs diffuses, céphlées, avec\\ndécouverte fortuite d\'une tacycardie à 135/ min .\\npas ed contage évident\\nvaccination COVID complète\\npatient tachycarde à 145 à l\'arrivée, sans fièvre, PA conservée,\\nsubfébrile à 37.8\\nToux sèche,\\nBDC rég, sans souffle pas de signe d\'insuffisance cardiaque\\nFR à 22/ min pas de signe de lutte, mv bilatéral et symétrique sans bruit surajouté,\\nabdo souple, dépressible, indolore,\\nneuro : spasticité diffuse pas de signe de localiation évident compte tenu de l\'état de base.\\nECG : tachycardie sinusale, sans toruble de la conduction ni de la repolarisation.\\n08/05/2021 23:39 : CUI Phillippa\\nBio : pas de sd inflammatoire\\ntropo nég\\nD dimères neg.\\nRadio de thorax : pas de foyer, pas de sd interstitiel .\\n09/05/2021 02:48 : CUI Phillippa\\nPatient qui est moins tachycarde apres antalgie et atarax.\\nTableau évocateur de virose;\\nRAD si moyen de transport pour RAD trouvé\\nTSH en externe pour bilan de tachycardie.\\nHémogramme/plaquettes 08/05/2021 21:00\\nCréatinine 08/05/2021 21:00\\nTemps de Quick (TP) 08/05/2021 21:00\\nCoronavirus SARS-CoV-2(PCR)-Ecouvillon Nasopharyngé 08/05/2021 21:00\\nTCA 08/05/2021 21:00\\nUrée 08/05/2021 21:00\\nD-Dimères 08/05/2021 21:00\\nEx. hépatique (PAL,ALAT,ASAT,GGT,Bili) 08/05/2021 21:00\\nIonogramme 08/05/2021 21:00\\nTroponine 08/05/2021 21:00\\nCRP 08/05/2021 21:00\\nHémoculture aé+ana (autres) 08/05/2021 21:00\\nSurv. fréquence respiratoire (FR) 08/05/2021 21:13\\nSurv. FC, PA, T° 08/05/2021 21:13\\nSurv. saturation pulsée en O2 (SPO2/ à préciser) \\nRadiographie du thorax 08/05/2021 21:47\\nRésultats de biologie :\\nNumération\\nLeucocytes ¦x10*9/L ¦6.23\\n¦4.00-10.00\\nHématies ¦x10*12/L¦4.66\\n¦4.00-6.20\\nHémoglobine ¦g/dL ¦13.5\\n¦12.0-18.0\\nHématocrite ¦% ¦39.1\\n- ¦40.0-55.0\\nVGM ¦fL ¦84\\n¦80-100\\nTCMH ¦pg ¦29.0\\n¦27.0-33.0\\nCCMH ¦g/dL ¦34.5\\n¦32.0-36.0\\nPlaquettes ¦x10*9/L ¦233\\n¦150-400\\nVMP ¦fL ¦11.3\\n+ ¦7.0-11.0\\nIDP ¦% ¦14.6\\n¦\\nFormule Sanguine\\nPolynucléaires ne…¹ ¦% ¦54.1\\n¦\\nPolynucléaires ne…¹ ¦x10*9/L ¦3.37\\n¦1.50-7.00\\nPolynucléaires éo…² ¦% ¦1.8\\n¦\\nPolynucléaires éo…² ¦x10*9/L ¦0.11\\n¦0.03-0.70\\nPolynucléaires ba…³ ¦% ¦0.6\\n¦\\nPolynucléaires ba…³ ¦x10*9/L ¦0.04\\n¦<0.10\\nLymphocytes ¦% ¦32.7\\n¦\\nLymphocytes ¦x10*9/L ¦2.04\\n¦1.50-4.00\\nMonocytes ¦% ¦10.8\\n¦\\nMonocytes ¦x10*9/L ¦0.67\\n¦0.10-1.00\\nGranuleux immatures ¦% ¦0.0\\n¦\\n¹\\nHEMATOLOGIE - HEMOSTASE\\nTraitement\\nTraitement antico…⁷ ¦ ¦Non indiqué.\\n¦\\n⁷ Traitement anticoagulant\\nTP\\nTemps de Quick pa…⁷ ¦s ¦14.5\\n¦\\nTemps de Quick té…⁷ ¦s ¦13.5\\n4/5CR Urgences SAT SAU ACCUEIL (UF), Imprimé le 09/05/2021 02:51\\nPat.: vanciu JANNON | M | 30/01/1996 | 8010143495 | 761236428\\n¦\\nTaux de prothrombine¦% ¦88\\n¦>70\\n⁷ Temps de Quick patient\\n⁷ Temps de Quick témoin\\nTCA\\nPatient ¦s ¦32.4\\n¦\\nTémoin ¦s ¦33.5\\n¦\\nRatio Patient/Témoin¦ ¦0.97\\n¦0.80-1.20\\nFibrinogène\\nFibrinogène activité¦g/L ¦2.97\\n¦1.80-4.00\\nD-dimères\\nD- ...

# %%
df_CR.note_text[1]
# Out:
# 'Compte-rendu de passage aux Urgences\\nAL.Score de tri : Score 2\\nMotif de tri : Dyspnée / insuffisance respiratoire\\nParamètres vitaux, à l\\\'accueil :\\nPA :155/70 mmHg FC : 84 /mn Temp : 36.5 °C FR : 30 /mn\\nSpO2 : 88% air\\nGCS : 15 (Y: 4/V: 5/M :6)\\nParamètres vitaux, dernière prise :\\nTA : 152/76 mmHg Temp : 36.4 °C FR : 22 /min SpO2 : 92 %\\nEVA : 0 CGS : 15\\n8\\nAntécédents\\n.37 Allergies :\\n- Pas d\\\'allergieconnue\\n59 Antécédents médicaux :\\n- AOMI stentée\\n3/06/1934 | 8006963017 | 2800038564\\nBPCO post tabagique\\nHTA\\nNodulte pulmonaire suspect en cours exploration\\nTraitements habituels\\ncf ordonnance scannée\\nMode de vie\\nvit au domicile avec sa femme\\npas d\\\'aide au domicile\\ntrouble cognitif débutant\\nAnamnèse\\nDétresse respiratoire amené par SP, vue par AR au domicile\\nSat 88 => SAUV\\na eu 1 serie d\\\'aerosol\\nPatient présentant des troubles de la mémoire : ne sait pas ce qu\\\'il fait ici, ne sait pas son âge.\\nBronchite chronique à priori sur tabagisme ancien\\nExamen clinique initial\\nPatient conscient, oxygénorequérant\\nAuscultation : sibilants + crépitants bilatéraux\\nAbdoment souple\\nMollets souples / pas d\\\'OMI\\nBilan cardio + Radio thorax\\nEvolution\\n07/11/2022 22:51 : OSMAN Sayed\\nECG = RSR à 77bpm, aspect BBD, ps de trouble de la repo\\nPCR COVID négative\\nExamens complémentaires\\nAngioscanner des artères pulmonaires 07/11/2022 18:18\\nRésultats de biologie :\\n______________________________________________________________________\\n_________________\\n106.37.97.35.658 ¦07/11/22\\n¦Valeurs de\\nAnalyse ¦Unité ¦13:45\\n¦réf.\\n¦ ¦Complet\\n¦\\n______________________________________________________________________\\n_________________\\nRENSEIGNEMENTS PRELEVEMENTS\\nPré-analytique\\nTransmission MPA 1 ¦ ¦0616\\n¦\\nBIOCHIMIE\\nExamens sanguins\\nSodium ¦mmol/L ¦145\\n¦135-146\\nPotassium ¦mmol/L ¦3.2\\n- ¦3.8-4.8\\nChlorure ¦mmol/L ¦105\\n¦98-107\\nCO2 total ¦mmol/L ¦26\\n¦22-29\\nTrou anionique ¦mmol/L ¦14\\n¦8-16\\nProtéines sériques ¦g/L ¦56\\n- ¦63-83\\nUrée ¦mmol/L ¦13.2\\n+ ¦2.6-8.1\\nDFG calculé par C…1 ¦mL/min/…¦47\\n- ¦90-120\\nCréatinine ¦µmol/L ¦120\\n+ ¦62-110\\nCRP ¦mg/L ¦61.0\\n+ ¦<5.0\\nASAT ¦U/L ¦29\\n¦<50\\nALAT ¦U/L ¦17\\n¦<50\\nGamma GT ¦U/L ¦60\\n¦<61\\nPhosphatases alca…2 ¦U/L ¦78\\n¦56-152\\nBilirubine totale ¦µmol/L ¦35\\n+ ¦<17\\nBilirubine conjuguée¦µmol/L ¦13\\n+ ¦<6\\nMarqueurs cardiaques - Sang\\nTroponine T (Hs) ¦ng/L ¦15\\n¦\\nValeurs normales ¦ ¦si >14 ng/L souffrance cardiaque\\npossi…3 ¦\\nNT Pro-BNP ¦ng/L ¦7411…4\\n¦\\nCOMPTE-RENDU BIOCHIMIE\\nCR - Pdf\\nCR Biochimie ¦ ¦PDF\\n¦\\n______________________________________________________________________\\n_________________\\n106192484715 ¦07/11/22\\n¦Valeurs de\\nAnalyse ¦Unité ¦13:25\\n¦réf.\\n¦ ¦Partiel\\n¦\\n______________________________________________________________________\\n_________________\\nHEMATOLOGIE - CYTOLOGIE\\nNumération\\nLeucocytes ¦x10*9/L ¦30.89\\n+ ¦4.00-10.00\\nHématies ¦x10*12/L¦4.46\\n¦4.20-5.90\\nHémoglobine ¦g/dL ¦13.9…1\\n¦13.0-17.0\\nHématocrite ¦L/L ¦0.43\\n¦0.40-0.54\\nVGM ¦fL ¦95.7\\n¦82.0-98.0\\nTCMH ¦pg ¦31.2\\n¦27.0-32.0\\nCCMH ¦g/dL ¦32.6\\n¦32.0-36.0\\nIDR ¦% ¦16.2\\n+ ¦<15.0\\nPlaquettes ¦x10*9/L ¦87\\n- ¦150-400\\nPlaquettes morpho…2 ¦ ¦Absence d\\\'amas plaquettaire.\\n¦\\n1 13.9\\npas de caillot visible\\n2 Plaquettes morphologie\\nFormule Sanguine\\nPolynucléaires ne…3 ¦% ¦33.0\\n¦\\nPolynucléaires ne…3 ¦x10*9/L ¦10.19\\n+ ¦1.50-7.00\\nPolynucléaires éo…4 ¦% ¦0.0\\n¦\\nPolynucléaires éo…4 ¦x10*9/L ¦0.00\\n¦<0.50\\nPolynucléaires ba…5 ¦% ¦0.0\\n¦\\nPolynucléaires ba…5 ¦x10*9/L ¦0.00\\n¦<0.20\\nLymphocytes ¦% ¦55.0\\n¦\\nLymphocytes ¦x10*9/L ¦16.99\\n+ ¦1.00-4.00\\nMonocytes ¦% ¦12.0\\n¦\\nMonocytes ¦x10*9/L ¦3.71\\n+ ¦0.10-1.00\\nHEMATOLOGIE - HEMOSTASE\\nTP\\nTemps de Quick pa…7 ¦s ¦16.7\\n¦\\nTaux de prothrombine¦% ¦72\\n¦>70\\n7 Temps de Quick patient\\nTCA\\nPatient ¦s ¦31\\n¦\\nTémoin ¦s ¦31.8\\n¦\\nRatio Patient/Témoin¦ ¦0.97\\n¦<1.20 ...

# %% [markdown]
# ## Mention positive d'Embolie Pulmonaire dans les CR_URGENCE

# %% [markdown]
# ### 1ère méthode avec l'application des fonctions nlp

# %%
df_EP=search_MTEV(df_CR)
# Out:
# 2024-05-23 11:35:51.786 | WARNING  | edsnlp.pipes.qualifiers.family.family:__init__:142 - You have requested that the pipeline use annotations provided by the `section` pipeline, but it was not set. Skipping that step.
# 2024-05-23 11:35:51.786 | WARNING  | edsnlp.pipes.misc.sections.sections:__init__:122 - The component Sections is still in Beta. Use at your own risks.
# 2it [00:00,  3.26it/s]

# %%
df_EP
# Out:
#    person_id visit_occurrence_id note_id note_class_source_value  \
# 0          2                None    None                 INCONNU
# 1          2                None    None                 INCONNU
#
#   lexical_variant label  negation  hypothesis  family  \
# 0         embolie    EP     False       False   False
# 1         embolie    EP     False       False   False
#
#                                             sentence section
# 0  nPas d\'argument pour une embolie pulmonaire j...    None
# 1         nCONCLUSION :\nPas d\'embolie pulmonaire.\    None

# %% [markdown]
# ## 2ème méthode: Extraction des patients avec embolie pulmonaire sans fonction

# %%
# Initialisation du pipeline NLP en dehors de la boucle
nlp = edsnlp.blank("eds")

regex_MTEV = {
    "EP": [
        r"(?i)embolie(?!.{0,10} graisseuse| m.?tastatique| septique| bact.?rienne| gazeuse)",
        r"(?i)t(|h)romb(us|i\W).{0,50}(pulmonaire|lobaire)",
        r"(?i)infarctus.{0,10}pulmonaire",
        r"\WE\.P\.\W",
        r"\WEP\W",
    ],
}

# Ajout des composants au pipeline
nlp.add_pipe("eds.matcher", config=dict(regex=regex_MTEV, ignore_excluded=True))
nlp.add_pipe("eds.sentences")
nlp.add_pipe("eds.negation")
nlp.add_pipe("eds.hypothesis")
nlp.add_pipe("eds.family")
nlp.add_pipe("eds.sections")

results = []
entities = []

# Traitement des textes du DataFrame
for i, text in enumerate(df_CR.note_text):
    doc = nlp(text)
    
    for ent in doc.ents:
        entity = {
            "id_patient": df_CR.person_id.iloc[i],
            "lexical_variant": ent.text,
            "label": ent.label_,
            "negation": ent._.negation,
            "hypothesis": ent._.hypothesis,
            "family": ent._.family,
            "sentence": ent.sent.text,
            "section": ent._.section
        }
        entities.append(entity)
        
        if not ent._.negation and not ent._.hypothesis:
            results.append(entity)

# Conversion des listes de résultats en DataFrame
df_EP = pd.DataFrame.from_records(results)
df_entities = pd.DataFrame.from_records(entities)
# Out:
# 2024-05-23 11:41:15.974 | WARNING  | edsnlp.pipes.qualifiers.family.family:__init__:142 - You have requested that the pipeline use annotations provided by the `section` pipeline, but it was not set. Skipping that step.
# 2024-05-23 11:41:15.974 | WARNING  | edsnlp.pipes.misc.sections.sections:__init__:122 - The component Sections is still in Beta. Use at your own risks.
# 2024-05-23 11:41:15.995 | WARNING  | edsnlp.pipes.misc.sections.sections:__init__:150 - You should add pipe `eds.normalizer`

# %%
df_entities
# Out:
#    id_patient lexical_variant label  negation  hypothesis  family  \
# 0           1         embolie    EP      True       False   False
# 1           2         embolie    EP     False       False   False
# 2           2         embolie    EP     False       False   False
#
#                                             sentence section
# 0  nTachycardie sans argument pour une embolie pu...    None
# 1  nPas d\'argument pour une embolie pulmonaire j...    None
# 2         nCONCLUSION :\nPas d\'embolie pulmonaire.\    None

# %%
df_EP
# Out:
#    id_patient lexical_variant label  negation  hypothesis  family  \
# 0           2         embolie    EP     False       False   False
# 1           2         embolie    EP     False       False   False
#
#                                             sentence section
# 0  nPas d\'argument pour une embolie pulmonaire j...    None
# 1         nCONCLUSION :\nPas d\'embolie pulmonaire.\    None
